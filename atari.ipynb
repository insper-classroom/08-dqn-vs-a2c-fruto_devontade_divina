# %%
from stable_baselines3 import DQN, A2C
from stable_baselines3.common.logger import configure
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import ale_py


gym.register_envs(ale_py)


os.makedirs("models", exist_ok=True)
os.makedirs("results/breakout2_a2c", exist_ok=True)
os.makedirs("results/breakout2_dqn", exist_ok=True)


total_timesteps = 1000000


a2c_log_path = "./results/breakout2_a2c"
dqn_log_path = "./results/breakout2_dqn"
a2c_logger = configure(a2c_log_path, ["csv", "stdout"])
dqn_logger = configure(dqn_log_path, ["csv", "stdout"])


env = make_atari_env('Breakout-v4', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)


model_dqn = DQN(
    policy="CnnPolicy",
    env=env,
    learning_rate=0.00025,
    buffer_size=100000,
    batch_size=32,
    gamma=0.99,
    target_update_interval=10000,
    exploration_fraction=0.2,
    exploration_initial_eps=1.0,
    exploration_final_eps=0.01,
    learning_starts=50000,
    device='cuda',
)

model_dqn.set_logger(dqn_logger)
print("Training DQN...")
model_dqn.learn(total_timesteps=total_timesteps)
model_dqn.save("models/dqn_breakout2")


mean_reward_dqn, std_reward_dqn = evaluate_policy(model_dqn, model_dqn.get_env(), n_eval_episodes=10)
print(f'DQN Mean reward: {mean_reward_dqn} +/- {std_reward_dqn:.2f}')


model_a2c = A2C(
    policy="CnnPolicy",
    env=env,
    learning_rate=0.0007,
    n_steps=128,
    gamma=0.99,
    gae_lambda=0.95,
    ent_coef=0.01,
    vf_coef=0.5,
    max_grad_norm=0.5,
    device='cuda',
)

model_a2c.set_logger(a2c_logger)
print("Training A2C...")
model_a2c.learn(total_timesteps=total_timesteps)
model_a2c.save("models/a2c_breakout2")


mean_reward_a2c, std_reward_a2c = evaluate_policy(model_a2c, model_a2c.get_env(), n_eval_episodes=10)
print(f'A2C Mean reward: {mean_reward_a2c} +/- {std_reward_a2c:.2f}')


try:
    a2c_log_data = pd.read_csv(f"{a2c_log_path}/progress.csv")
    dqn_log_data = pd.read_csv(f"{dqn_log_path}/progress.csv")
    
    a2c_log_data['Algorithm'] = 'A2C'
    dqn_log_data['Algorithm'] = 'DQN'

    sns.set_theme(style="darkgrid")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

    sns.lineplot(x="time/total_timesteps", y="rollout/ep_rew_mean", data=dqn_log_data, ax=ax1, color="blue")
    ax1.set_title(f"DQN Training ({total_timesteps} timesteps)", fontsize=12)
    ax1.set_xlabel("Timesteps", fontsize=10)
    ax1.set_ylabel("Mean Episode Reward", fontsize=10)
    ax1.grid(True, alpha=0.3)

    sns.lineplot(x="time/total_timesteps", y="rollout/ep_rew_mean", data=a2c_log_data, ax=ax2, color="orange")
    ax2.set_title(f"A2C Training ({total_timesteps} timesteps)", fontsize=12)
    ax2.set_xlabel("Timesteps", fontsize=10)
    ax2.set_ylabel("")
    ax2.grid(True, alpha=0.3)

    y_min = min(dqn_log_data["rollout/ep_rew_mean"].min(), a2c_log_data["rollout/ep_rew_mean"].min()) - 10
    y_max = max(dqn_log_data["rollout/ep_rew_mean"].max(), a2c_log_data["rollout/ep_rew_mean"].max()) + 10
    
    ax1.set_ylim(y_min, y_max)
    ax2.set_ylim(y_min, y_max)

    plt.tight_layout()
    plt.show()

except FileNotFoundError as e:
    print(f"Error loading log files: {e}")
    print("Please check if the CSV files were created in the results directory.")

env.close()
# Out:
# Logging to ./results/breakout2_a2c
# Logging to ./results/breakout2_dqn
# Training DQN...
# /home/andre/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/buffers.py:241: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 5.65GB > 2.72GB
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 141      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 25       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 256      |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 293      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 94       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 301      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 271      |
# |    ep_rew_mean      | 1.33     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 325      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 360      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 227      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 381      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 281      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | 1.8      |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 387      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 332      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | 1.83     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 382      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 356      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 402      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 449      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 318      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 407      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 318      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 416      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 553      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 319      |
# |    ep_rew_mean      | 2        |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 412      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 579      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 312      |
# |    ep_rew_mean      | 1.9      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 418      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 637      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 313      |
# |    ep_rew_mean      | 1.91     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 418      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 678      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 415      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 304      |
# |    ep_rew_mean      | 1.75     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 418      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 744      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | 1.69     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 418      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 790      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 415      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 814      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 413      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 841      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 415      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 893      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 1.62     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 419      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 959      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | 1.71     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 420      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1009     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 299      |
# |    ep_rew_mean      | 1.72     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 419      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 298      |
# |    ep_rew_mean      | 1.74     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 421      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | 1.7      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 421      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | 1.7      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 422      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 1.67     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 421      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1203     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 1.64     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 422      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 1.65     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 420      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 418      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 419      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | 1.6      |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 417      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 1.58     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 418      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 286      |
# |    ep_rew_mean      | 1.59     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 417      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 416      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1501     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 1.57     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 415      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1526     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 284      |
# |    ep_rew_mean      | 1.55     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 415      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 1.5      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 414      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1595     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 51
#      49 model_dqn.set_logger(dqn_logger)
#      50 print("Training DQN...")
# ---> 51 model_dqn.learn(total_timesteps=total_timesteps)
#      52 model_dqn.save("models/dqn_breakout2")
#      55 mean_reward_dqn, std_reward_dqn = evaluate_policy(model_dqn, model_dqn.get_env(), n_eval_episodes=10)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py:39, in VecFrameStack.step_wait(self)
#      30 def step_wait(
#      31     self,
#      32 ) -> Tuple[
#    (...)
#      36     List[Dict[str, Any]],
#      37 ]:
#      38     observations, rewards, dones, infos = self.venv.step_wait()
# ---> 39     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      40     return observations, rewards, dones, infos
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/stable_baselines3/common/vec_env/stacked_observations.py:157, in StackedObservations.update(self, observations, dones, infos)
#     154     return stacked_obs, infos
#     156 shift = -observations.shape[self.stack_dimension]
# --> 157 self.stacked_obs = np.roll(self.stacked_obs, shift, axis=self.stack_dimension)
#     158 for env_idx, done in enumerate(dones):
#     159     if done:
#
# File <__array_function__ internals>:200, in roll(*args, **kwargs)
#
# File ~/miniconda3/envs/cuda/lib/python3.8/site-packages/numpy/core/numeric.py:1249, in roll(a, shift, axis)
#    1247 for indices in itertools.product(*rolls):
#    1248     arr_index, res_index = zip(*indices)
# -> 1249     result[res_index] = a[arr_index]
#    1251 return result
#
# KeyboardInterrupt:
